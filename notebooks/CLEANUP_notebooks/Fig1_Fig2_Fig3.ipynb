# %%
import xarray as xr
import scipy
import scipy.io
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seawater as sw
import cmocean
import matplotlib.patches as patches
import cartopy.crs as ccrs
from matplotlib.offsetbox import AnchoredText
import xorca_brokenline as bl
import string
import warnings

warnings.filterwarnings("ignore")

# %%
def depth_weighted_mean(S_T_thresh, dim=None):
    diff_z = np.diff(S_T_thresh.deptht)
    dz = np.insert(diff_z, 0, diff_z.mean())
    mask = xr.where(S_T_thresh > -50, 1, np.nan)
    dz_masked = dz[None, :, None, None] * mask
    dz_sum_masked = dz_masked.sum(dim="deptht")
    # making mask of ones and nans -- mask changes per year (ones and nans) since depth changes per year
    weighted_depth_mean = (S_T_thresh * dz_masked).sum(
        dim="deptht"
    ).squeeze() / dz_sum_masked
    # weighted_depth_mean_ts = weighted_depth_mean.mean(dim=dim)
    return weighted_depth_mean


def detrend_dim(da, dim, deg=1):
    # detrend along a single dimension
    p = da.polyfit(dim=dim, deg=deg)
    fit = xr.polyval(da[dim], p.polyfit_coefficients)
    return fit, da - fit


def select_data(data):
    north_sel = data.isel(y=slice(300, None), x=slice(300, None))
    return north_sel

# %% [markdown]
# ## Figure 1

# %%
inpath = "/gxfs_work/geomar/smomw452/GLORYS12/Data/"
mesh_mask = xr.open_dataset(inpath + "mesh_masks/combined_mesh_mask.nc")
bathy = mesh_mask.hdept.isel(t=0)
land_mask = mesh_mask.tmaskutil.isel(t=0).where(mesh_mask.tmaskutil.isel(t=0) != 0)
lon, lat = mesh_mask.nav_lon, mesh_mask.nav_lat

ds_U = xr.open_mfdataset(inpath + "U_monthly/*.nc", combine="by_coords").vozocrtx
ds_V = xr.open_mfdataset(inpath + "V_monthly/*.nc", combine="by_coords").vomecrty

U = select_data(ds_U)
V = select_data(ds_V)

U_600_1300m_mean = depth_weighted_mean(U.sel(deptht=slice(600, 1300)))

V_600_1300m_mean = depth_weighted_mean(V.sel(deptht=slice(600, 1300)))

speed = np.sqrt(U_600_1300m_mean**2 + V_600_1300m_mean**2)

mean_speed = speed.mean(dim="time_counter").load()

U_600_1300m_mean = U_600_1300m_mean.mean(dim="time_counter").compute()
V_600_1300m_mean = V_600_1300m_mean.mean(dim="time_counter").compute()

mean_speed_mask = xr.where((mean_speed > 0.02) & (mean_speed < 0.1), 1, 0)

mesh_mask_slice = select_data(mesh_mask)
bathy_slice = mesh_mask_slice.hdept.isel(t=0)
land_mask_slice = mesh_mask_slice.tmaskutil.isel(t=0).where(
    mesh_mask_slice.tmaskutil.isel(t=0) != 0
)
lon_slice, lat_slice = mesh_mask_slice.nav_lon, mesh_mask_slice.nav_lat

# %%
plt.rcParams.update({"font.size": 13})  # Change 14 to your desired font size

# %%
mean_speed_masked = mean_speed.where(
    mean_speed < 10
)  # ocean speeds are never ~1e37 m/s

# %%
mean_speed_masked.plot()

# %%
mean_speed.plot()

# %%
fig = plt.figure(figsize=(25, 8))

# Main figure (larger map)
ax_main = fig.add_subplot(
    1, 1, 1, projection=ccrs.Orthographic(central_longitude=-10, central_latitude=77)
)
# ax_main.set_extent([-40, 20, 55, 85], crs=ccrs.PlateCarree())
ax_main.set_extent([-20, 10, 59, 80], crs=ccrs.PlateCarree())


pcolormesh = ax_main.pcolormesh(
    mesh_mask.nav_lon,
    mesh_mask.nav_lat,
    bathy,
    cmap="Blues",
    vmin=0,
    vmax=3500,
    transform=ccrs.PlateCarree(),
)
cbar = plt.colorbar(
    pcolormesh, ax=ax_main, orientation="horizontal", pad=0.08, shrink=0.2
)
cbar.set_label("bathymetry (m)")
ax_main.coastlines()

gl = ax_main.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlocator = plt.FixedLocator(np.arange(-180, 181, 10))
gl.ylocator = plt.FixedLocator(np.arange(-90, 91, 10))
gl.xlabel_style = {"size": 10}
gl.ylabel_style = {"size": 10}

rectangle = patches.Rectangle(
    (-20, 59),
    width=30,
    height=11,
    edgecolor="gray",
    facecolor="none",
    linewidth=2,
    transform=ccrs.PlateCarree(),
)
ax_main.add_patch(rectangle)

# sections
ax_main.plot(
    [5.5, -1],
    [62.24, 65.0],
    color="tab:pink",
    label="Svinoy section",
    linewidth=3,
    transform=ccrs.PlateCarree(),
)
ax_main.plot(
    [-6.43, -6.43],
    [62.15, 64.5],
    color="tab:green",
    label="N section",
    linewidth=3,
    transform=ccrs.PlateCarree(),
)
# ax_main.plot([-15, -11.95], [66.25, 68.7], color='blue', label='LN section', transform=ccrs.PlateCarree())
ax_main.plot(
    [-6.5, -2.5], [61.3, 60.3], color="k", linewidth=3, transform=ccrs.PlateCarree()
)


inset_ax = fig.add_axes(
    [0.45, 0.35, 0.4, 0.4],
    projection=ccrs.Orthographic(central_longitude=-10, central_latitude=77),
)
inset_ax.set_extent([-17, 5, 59, 70], crs=ccrs.PlateCarree())


pcolormesh = inset_ax.pcolormesh(
    select_data(mesh_mask.nav_lon),
    select_data(mesh_mask.nav_lat),
    mean_speed_masked,
    cmap=cmocean.cm.dense,
    vmin=0,
    vmax=0.1,
    transform=ccrs.PlateCarree(),
)
inset_ax.coastlines()

cbar_inset_ax = fig.add_axes(
    [0.725, 0.35, 0.01, 0.4]
)  # Adjust the position and size as needed
cbar_inset = plt.colorbar(pcolormesh, cax=cbar_inset_ax)
cbar_inset.set_label("speed (m/s)")

inset_gl = inset_ax.gridlines(
    draw_labels=False, dms=True, x_inline=False, y_inline=False
)


inset_ax.plot(
    [5.5, -1],
    [62.24, 65.0],
    color="tab:pink",
    linewidth=3,
    transform=ccrs.PlateCarree(),
)
inset_ax.plot(
    [-6.43, -6.43],
    [62.15, 64.5],
    color="tab:green",
    linewidth=3,
    transform=ccrs.PlateCarree(),
)
# inset_ax.plot([-15, -11.95], [66.25, 68.7], color='blue', transform=ccrs.PlateCarree())
inset_ax.plot(
    [-6.5, -2.5], [61.3, 60.3], color="k", linewidth=3, transform=ccrs.PlateCarree()
)


point_main1 = (10, 70)

point_inset1 = (32, 71.3)  # 40, 73.5

point_main2 = (10, 59)

point_inset2 = (13, 57.8)  # (15, 55.4)

ax_main.plot(
    [point_main1[0], point_inset1[0]],
    [point_main1[1], point_inset1[1]],
    "gray",
    linewidth=2,
    transform=ccrs.PlateCarree(),
)

ax_main.plot(
    [point_main2[0], point_inset2[0]],
    [point_main2[1], point_inset2[1]],
    "gray",
    linewidth=2,
    transform=ccrs.PlateCarree(),
)


# add U, V vectors
skip = 5
inset_ax.quiver(
    select_data(mesh_mask.nav_lon).values[::skip, ::skip],
    select_data(mesh_mask.nav_lat).values[::skip, ::skip],
    (mean_speed_mask * U_600_1300m_mean).values[::skip, ::skip],
    (mean_speed_mask * V_600_1300m_mean).values[::skip, ::skip],
    color="k",
    scale=1,
    transform=ccrs.PlateCarree(),
)

# plt.savefig("Fig1_bathy_sections.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Figure 2

# %%
## add observations

inpth = "/gxfs_work/geomar/smomw452/GLORYS12/Data/observations/"
FBC_overflow_trspt = pd.read_csv(
    inpth + "FBC_overflow_transport.txt", delim_whitespace=True
)

Annual_FB_bottom_temp = pd.read_csv(
    inpth + "Annual_FB_bottom_temp.txt", delim_whitespace=True
)
Annual_FC_bottom_temp = pd.read_csv(
    inpth + "Annual_FC_bottom_temp.txt", delim_whitespace=True
)
Annual_S_section_salinity = pd.read_csv(inpth + "S06_S08_st.txt", delim_whitespace=True)


# convert decimal year to datetime
def decimal_year_to_datetime(decimal_year):
    year = int(decimal_year)
    fractional_year = decimal_year - year
    start_of_year = pd.Timestamp(f"{year}-01-01")
    days_in_year = 365
    days_passed = int(fractional_year * days_in_year)
    return start_of_year + pd.Timedelta(days=days_passed)


FBC_overflow_trspt["Date"] = FBC_overflow_trspt["Year"].apply(decimal_year_to_datetime)

FBC_overflow_trspt["Date"] = pd.to_datetime(FBC_overflow_trspt["Date"])


# setting date as the index
FBC_overflow_trspt.set_index("Date", inplace=True)
FBC_overflow_trspt_annual_means = FBC_overflow_trspt["Flux"].resample("Y").mean()
FBC_overflow_trspt_annual_means.plot(color="k")
plt.title("Larsen et al 2024")
plt.show()

cmap_vel = plt.get_cmap("bwr")
cmap_vel.set_bad(color="gray")

cmap_sal = plt.get_cmap("PuOr_r")
cmap_sal.set_bad(color="gray")


cmap_temp = plt.get_cmap("RdBu_r")
cmap_temp.set_bad(color="gray")

# %%
# load cross sections
inpath = "/gxfs_work/geomar/smomw452/GLORYS12/Data/"
S = xr.open_dataset(inpath + "S_section.nc")
S_2021_2024 = xr.open_dataset(inpath + "S_section_2021_2024.nc")

S = xr.concat([S, S_2021_2024], dim="time_counter").sel(
    time_counter=slice("1993", "2020")
)


S_sigma0 = (
    xr.apply_ufunc(
        sw.eos80.dens0,
        S.vosaline,
        S.votemper,
        dask="parallelized",
        output_dtypes=[np.float64],
    )
    - 1000
)
S_overflow = S.where(S_sigma0 > 28)

N = xr.open_dataset(inpath + "N_section.nc")
N_2021_2024 = xr.open_dataset(inpath + "N_section_2021_2024.nc")

N = xr.concat([N, N_2021_2024], dim="time_counter").sel(
    time_counter=slice("1993", "2020")
)


## density referenced to the surface
N_sigma0 = (
    xr.apply_ufunc(
        sw.eos80.dens0,
        N.vosaline,
        N.votemper,
        dask="parallelized",
        output_dtypes=[np.float64],
    )
    - 1000
)
N_overflow = N.where((N_sigma0 > 27.985))  # & (N_sigma0 < 28.02) 27.985

N_obs = xr.open_dataset(inpath + "GSR_FAROECURR_SSN_CTD_1m_1987_2023.nc").sel(
    TIME=slice("1993", "2020")
)
N_obs_sigma0 = (
    xr.apply_ufunc(
        sw.eos80.dens0,
        N_obs.SAL,
        N_obs.TMP,
        dask="parallelized",
        output_dtypes=[np.float64],
    )
    - 1000
)
N_obs_overflow = N_obs.where((N_obs_sigma0 > 28))  # 28, 27.985

# %%
## load section S observation files
inpath = "/gxfs_work/geomar/smomw452/GLORYS12/Data/"
S_obs = scipy.io.loadmat(inpath + "S.mat")

# Inspect contents
print(S_obs.keys())


def sq(x):
    return np.squeeze(x)


# for k in ["SS", "F", "O", "S", "T", "qf_F", "qf_O", "qf_S", "qf_T"]:
#     print(k, sq(S_obs[k]).shape)

F_mat = sq(S_obs["F"]).transpose(2, 1, 0)
S_mat = sq(S_obs["S"]).transpose(2, 1, 0)
T_mat = sq(S_obs["T"]).transpose(2, 1, 0)
qf_F_mat = sq(S_obs["qf_F"]).transpose(2, 1, 0)
qf_O_mat = sq(S_obs["qf_O"]).transpose(2, 1, 0)
qf_S_mat = sq(S_obs["qf_S"]).transpose(2, 1, 0)
qf_T_mat = sq(S_obs["qf_T"]).transpose(2, 1, 0)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'None', 'SS', 'F', 'O', 'S', 'T', 'qf_F', 'qf_O', 'qf_S', 'qf_T', '__function_workspace__'])

# %%
# Time information
time_df = pd.read_csv(inpath + "S_time.csv")

# Station metadata
stations_df = pd.read_csv(inpath + "S_stations.csv")

time_df["time"] = pd.to_datetime(
    dict(year=time_df["y"], month=time_df["m"], day=time_df["d"])
)

nt = S_mat.shape[0]
time = time_df["time"].values[:nt]

station = stations_df["stodnavn"].values
lat = stations_df["lat"].values
lon = stations_df["lon"].values

coords_time = {
    "time": time,
    "cruise": ("time", time_df["cruise"].values[:nt]),
    "dayofyear": ("time", time_df["dayno"].values[:nt]),
}

coords_station = {
    "station": station,
    "lat": ("station", lat),
    "lon": ("station", lon),
}

coords = {
    "time": time,
    "station": station,
    "lat": ("station", lat),
    "lon": ("station", lon),
    "cruise": ("time", time_df["cruise"].values[:nt]),
    "dayofyear": ("time", time_df["dayno"].values[:nt]),
    "depth": np.arange(0, 1070),  # or your real depth array
}

S_obs = xr.Dataset(
    data_vars=dict(
        S=(("time", "station", "depth"), S_mat),
        T=(("time", "station", "depth"), T_mat),
    ),
    coords=coords,
)

S_obs_sigma0 = (
    xr.apply_ufunc(
        sw.eos80.dens0,
        S_obs.S,
        S_obs.T,
        dask="parallelized",
        output_dtypes=[np.float64],
    )
    - 1000
)

S_obs_overflow = S_obs.where((S_obs_sigma0 > 28)).sel(
    time=slice("1996", "2020")
)  # 28, 27.985

# %%
## testing


time_df = pd.read_csv(inpath + "S_time.csv")
stations_df = pd.read_csv(inpath + "S_stations.csv")
time_df["time"] = pd.to_datetime(
    dict(year=time_df["y"], month=time_df["m"], day=time_df["d"])
)
nt = S_mat.shape[0]
time = time_df["time"].values[:nt]
station = stations_df["stodnavn"].values
lat = stations_df["lat"].values
lon = stations_df["lon"].values
coords = {
    "time": time,
    "station": station,
    "lat": ("station", lat),
    "lon": ("station", lon),
    "cruise": ("time", time_df["cruise"].values[:nt]),
    "dayofyear": ("time", time_df["dayno"].values[:nt]),
    "depth": np.arange(0, 1070),
}
S_obs = xr.Dataset(
    data_vars=dict(
        S=(("time", "station", "depth"), S_mat),
        T=(("time", "station", "depth"), T_mat),
    ),
    coords=coords,
)

# Apply station exclusion to S_obs itself
stations_to_exclude = ["S11", "S15", "S16", "S17", "S18", "S19"]
stations_to_keep = [s for s in S_obs.station.values if s not in stations_to_exclude]
S_obs = S_obs.sel(station=stations_to_keep)

S_obs_sigma0 = (
    xr.apply_ufunc(
        sw.eos80.dens0,
        S_obs.S,
        S_obs.T,
        dask="parallelized",
        output_dtypes=[np.float64],
    )
    - 1000
)
S_obs_overflow = S_obs.where((S_obs_sigma0 > 28)).sel(time=slice("1996", "2020"))

# %%
S_trspt_detrend = detrend_dim(
    bl.calculate_transport(S.sel(z=slice(500, None)))
    .trsp.rolling(time_counter=12, center=True)
    .mean(),
    dim="time_counter",
)[1].sel(time_counter=slice("1996", "2020"))

# %%
S_land_mask = xr.where(S.vosaline.isel(time_counter=0) > 0, 1, np.nan)
N_land_mask = xr.where(N.vosaline.isel(time_counter=0) > 0, 1, np.nan)

# %%
plt.rcParams.update({"font.size": 14})

# %%
fig, axs = plt.subplots(5, 2, figsize=(13, 20))  # 5 rows x 2 columns

# --- Column headers ---
fig.text(0.30, 0.92, "Section S", ha="center", fontsize=16, fontweight="bold")
fig.text(0.72, 0.92, "Section N", ha="center", fontsize=16, fontweight="bold")

# [0,0] S Salinity GLORYS
x = axs[0, 0].pcolormesh(
    S.c / 1e3,
    -S.z,
    S.vosaline.mean("time_counter"),
    cmap=cmap_sal,
    vmin=34.8,
    vmax=35.3,
)
CS = axs[0, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    [27.4, 27.5, 27.8, 28.0],
    colors="gray",
)
axs[0, 0].clabel(CS, fontsize=12)
axs[0, 0].set_ylim(-1200, 0)
axs[0, 0].set_ylabel("Depth (m)")
axs[0, 0].set_title("GLORYS12  |  Salinity", loc="left", fontsize=11)
axs[0, 0].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[0, 0]).set_label("psu")
# axs[0, 0].contour(
#     S.c / 1e3, -S.z,
#     xr.where((-S.u_rot_normal.mean("time_counter") < 0) & (S_sigma0.mean("time_counter") > 28), 1, 0) * S_land_mask,
#     levels=0, colors="k", linestyles="dashed",
# )

axs[0, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    levels=[28],
    colors="k",
    linestyles="dashed",
    linewidths=1.5,
)

# [0,1] N Salinity GLORYS
x = axs[0, 1].pcolormesh(
    N.c / 1e3,
    -N.z,
    N.vosaline.mean("time_counter"),
    cmap=cmap_sal,
    vmin=34.8,
    vmax=35.3,
)
CS = axs[0, 1].contour(
    N.c / 1e3,
    -N.z,
    N_sigma0.mean("time_counter"),
    [27.8, 28.02, 28.05, 28.06, 28.07, 28.08],
    colors="gray",
)
axs[0, 1].clabel(CS, fontsize=12)
axs[0, 1].set_ylim(-2000, 0)
axs[0, 1].set_ylabel("Depth (m)")
axs[0, 1].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[0, 1]).set_label("psu")
axs[0, 1].contour(
    N.c / 1e3,
    -N.z,
    xr.where(
        (N.u_rot_normal.mean("time_counter") > 0.01)
        & (N_sigma0.mean("time_counter") > 28),
        1,
        0,
    )
    * N_land_mask,
    levels=0,
    colors="k",
    linestyles="dashed",
)

# [1,0] S Temperature GLORYS
x = axs[1, 0].pcolormesh(
    S.c / 1e3,
    -S.z,
    S.votemper.mean("time_counter"),
    cmap=cmap_temp,
    vmin=-1,
    vmax=10,
)
CS = axs[1, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    [27.4, 27.5, 27.8, 28.0],
    colors="gray",
)
axs[1, 0].clabel(CS, fontsize=12)
axs[1, 0].set_ylim(-1200, 0)
axs[1, 0].set_ylabel("Depth (m)")
axs[1, 0].set_title("GLORYS12  |  Temperature", loc="left", fontsize=11)
axs[1, 0].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[1, 0]).set_label("°C")
# axs[1, 0].contour(
#     S.c / 1e3, -S.z,
#     xr.where((-S.u_rot_normal.mean("time_counter") < 0) & (S_sigma0.mean("time_counter") > 28), 1, 0) * S_land_mask,
#     levels=0, colors="k", linestyles="dashed",
# )

axs[1, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    levels=[28],
    colors="k",
    linestyles="dashed",
    linewidths=1.5,
)


# [1,1] N Temperature GLORYS
x = axs[1, 1].pcolormesh(
    N.c / 1e3,
    -N.z,
    N.votemper.mean("time_counter"),
    cmap=cmap_temp,
    vmin=-1,
    vmax=10,
)
CS = axs[1, 1].contour(
    N.c / 1e3,
    -N.z,
    N_sigma0.mean("time_counter"),
    [27.8, 28.02, 28.05, 28.06, 28.07, 28.08],
    colors="gray",
)
axs[1, 1].clabel(CS, fontsize=12)
axs[1, 1].set_ylim(-2000, 0)
axs[1, 1].set_ylabel("Depth (m)")
axs[1, 1].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[1, 1]).set_label("°C")
axs[1, 1].contour(
    N.c / 1e3,
    -N.z,
    xr.where(
        (N.u_rot_normal.mean("time_counter") > 0.01)
        & (N_sigma0.mean("time_counter") > 28),
        1,
        0,
    )
    * N_land_mask,
    levels=0,
    colors="k",
    linestyles="dashed",
)

# [2,0] S Salinity obs
x = axs[2, 0].pcolormesh(
    S_obs.lon,
    -S_obs.depth,
    S_obs.S.mean("time").T,
    cmap=cmap_sal,
    vmin=34.8,
    vmax=35.3,
)
CS = axs[2, 0].contour(
    S_obs.lon,
    -S_obs.depth,
    S_obs_sigma0.mean("time").T,
    [27.4, 27.5, 27.8, 28.0],
    colors="gray",
)
axs[2, 0].clabel(CS, fontsize=12)
axs[2, 0].set_ylim(-1070, 0)
axs[2, 0].set_ylabel("Depth (m)")
axs[2, 0].set_title("Observations  |  Salinity", loc="left", fontsize=11)
axs[2, 0].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[2, 0]).set_label("psu")

# [2,1] N Salinity obs
x = axs[2, 1].pcolormesh(
    np.arange(0, 300, 23),
    -N_obs.DEPTH,
    N_obs.SAL.T.mean("TIME"),
    cmap=cmap_sal,
    vmin=34.8,
    vmax=35.3,
)
CS = axs[2, 1].contour(
    np.arange(0, 300, 23),
    -N_obs.DEPTH,
    N_obs_sigma0.T.mean("TIME"),
    [27.8, 28.02, 28.05, 28.06, 28.07],
    colors="gray",
)
axs[2, 1].clabel(CS, fontsize=12)
axs[2, 1].set_ylim(-2000, 0)
axs[2, 1].set_ylabel("Depth (m)")
axs[2, 1].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[2, 1]).set_label("psu")

# [3,0] S Temperature obs
x = axs[3, 0].pcolormesh(
    S_obs.lon,
    -S_obs.depth,
    S_obs.T.mean("time").T,
    cmap=cmap_temp,
    vmin=-1,
    vmax=10,
)
CS = axs[3, 0].contour(
    S_obs.lon,
    -S_obs.depth,
    S_obs_sigma0.mean("time").T,
    [27.4, 27.5, 27.8, 28.0],
    colors="gray",
)
axs[3, 0].clabel(CS, fontsize=12)
axs[3, 0].set_ylim(-1070, 0)
axs[3, 0].set_ylabel("Depth (m)")
axs[3, 0].set_title("Observations  |  Temperature", loc="left", fontsize=11)
axs[3, 0].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[3, 0]).set_label("°C")

# [3,1] N Temperature obs
x = axs[3, 1].pcolormesh(
    np.arange(0, 300, 23),
    -N_obs.DEPTH,
    N_obs.TMP.T.mean("TIME"),
    cmap=cmap_temp,
    vmin=-1,
    vmax=10,
)
CS = axs[3, 1].contour(
    np.arange(0, 300, 23),
    -N_obs.DEPTH,
    N_obs_sigma0.T.mean("TIME"),
    [27.8, 28.02, 28.05, 28.06, 28.07],
    colors="gray",
)
axs[3, 1].clabel(CS, fontsize=12)
axs[3, 1].set_ylim(-2000, 0)
axs[3, 1].set_ylabel("Depth (m)")
axs[3, 1].tick_params(labelbottom=False)
plt.colorbar(x, ax=axs[3, 1]).set_label("°C")

# [4,0] S Velocity
x = axs[4, 0].pcolormesh(
    S.c / 1e3,
    -S.z,
    -S.u_rot_normal.mean("time_counter"),
    cmap=cmap_vel,
    vmin=-0.2,
    vmax=0.2,
)
CS = axs[4, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    [27.4, 27.5, 27.8, 28.0],
    colors="gray",
)
axs[4, 0].clabel(CS, fontsize=12)
axs[4, 0].set_ylim(-1200, 0)
axs[4, 0].set_xlabel("Distance (km)")
axs[4, 0].set_ylabel("Depth (m)")
axs[4, 0].set_title("GLORYS12  |  Velocity", loc="left", fontsize=11)
plt.colorbar(x, ax=axs[4, 0]).set_label("m/s")
# axs[4, 0].contour(
#     S.c / 1e3, -S.z,
#     xr.where((-S.u_rot_normal.mean("time_counter") < 0) & (S_sigma0.mean("time_counter") > 28), 1, 0) * S_land_mask,
#     levels=0, colors="k", linestyles="dashed",
# )
axs[4, 0].contour(
    S.c / 1e3,
    -S.z,
    S_sigma0.mean("time_counter"),
    levels=[28],
    colors="k",
    linestyles="dashed",
    linewidths=1.5,
)


# [4,1] N Velocity
x = axs[4, 1].pcolormesh(
    N.c / 1e3,
    -N.z,
    N.u_rot_normal.mean("time_counter"),
    cmap=cmap_vel,
    vmin=-0.2,
    vmax=0.2,
)
CS = axs[4, 1].contour(
    N.c / 1e3,
    -N.z,
    N_sigma0.mean("time_counter"),
    [27.8, 28.02, 28.05, 28.06, 28.07, 28.08],
    colors="gray",
)
axs[4, 1].clabel(CS, fontsize=12)
axs[4, 1].set_ylim(-2000, 0)
axs[4, 1].set_xlabel("Distance (km)")
axs[4, 1].set_ylabel("Depth (m)")
plt.colorbar(x, ax=axs[4, 1]).set_label("m/s")
axs[4, 1].contour(
    N.c / 1e3,
    -N.z,
    xr.where(
        (N.u_rot_normal.mean("time_counter") > 0.01)
        & (N_sigma0.mean("time_counter") > 28),
        1,
        0,
    )
    * N_land_mask,
    levels=0,
    colors="k",
    linestyles="dashed",
)

############################################
# Panel labels
############################################
labels = [f"{letter})" for letter in string.ascii_lowercase[:10]]
for i, ax in enumerate(axs.flat):
    ax.text(
        -0.1,
        1.05,
        labels[i],
        transform=ax.transAxes,
        fontsize=13,
        ha="right",
        va="bottom",
        fontweight="bold",
    )

plt.subplots_adjust(wspace=0.3, hspace=0.32, top=0.90)
# plt.savefig('Fig2_S_N_section_obs.png', dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Figure 3

# %%
def weighted_mean(data):
    # mask = xr.where(data.u_normal > 0,1,np.nan)
    gb_area = data.dx * data.dz  # mask* mask*
    numerator = (
        (data * gb_area).squeeze().sum(["z", "c"])
    )  # if want to depth average over range of depths, use native grid! .isel(z=slice...).then sum over z, y, and x
    denominator = (gb_area).sum(["c", "z"]).squeeze()
    div = numerator / denominator
    return div


convert_abSal_psu = 1.0047154


def depth_weighted_mean(S_T_thresh, dim=None):
    diff_z = np.diff(S_T_thresh.deptht)
    dz = np.insert(diff_z, 0, diff_z.mean())
    mask = xr.where(S_T_thresh > -50, 1, np.nan)
    dz_masked = dz[None, :, None, None] * mask
    dz_sum_masked = dz_masked.sum(dim="deptht")
    # making mask of ones and nans -- mask changes per year (ones and nans) since depth changes per year
    weighted_depth_mean = (S_T_thresh * dz_masked).sum(
        dim="deptht"
    ).squeeze() / dz_sum_masked
    # weighted_depth_mean_ts = weighted_depth_mean.mean(dim=dim)
    return weighted_depth_mean


def detrend_dim(da, dim, deg=1):
    # detrend along a single dimension
    p = da.polyfit(dim=dim, deg=deg)
    fit = xr.polyval(da[dim], p.polyfit_coefficients)
    return fit, da - fit


def select_data(data):
    north_sel = data.isel(y=slice(300, None), x=slice(300, None))
    return north_sel

# %%
# Create 3 rows, 2 columns
fig, axs = plt.subplots(2, 2, figsize=(14, 8), sharex=False)
# axs is 3x2 array

############################################
# --------- Row 1: Temperature -------------
############################################

# S section (left)
axs[0, 0].plot(
    Annual_FB_bottom_temp["Year"][:23],
    Annual_FB_bottom_temp["Tcom"][:23],
    color="tab:blue",
    linestyle="dashed",
    label="FBC (observations)",
)
axs[0, 0].plot(
    np.arange(1993, 2021, 1),
    weighted_mean(S_overflow)
    .votemper.groupby("time_counter.year")
    .mean(dim="time_counter"),
    label="S section (GLORYS12)",
    color="k",
)

axs[0, 0].plot(
    S_obs_overflow.T.mean(dim=("station", "depth"))
    .groupby("time.year")
    .mean(dim="time")
    .year,
    S_obs_overflow.T.mean(dim=("station", "depth"))
    .groupby("time.year")
    .mean(dim="time"),
    color="k",
    linestyle="dashed",
    linewidth=2,
    label="S section (observations)",
)


axs[0, 0].set_ylabel("Temperature (°C)")
axs[0, 0].set_ylim(-0.65, -0.0)
axs[0, 0].grid()
axs[0, 0].add_artist(
    AnchoredText("a)", prop=dict(size=15), frameon=True, loc="lower left")
)
axs[0, 0].legend(loc=("upper left"))

# N section (right)
axs[0, 1].plot(
    N_obs_overflow.mean(dim=("STATION", "DEPTH"))
    .TMP.groupby("TIME.year")
    .mean(dim="TIME")
    .year,
    N_obs_overflow.mean(dim=("STATION", "DEPTH"))
    .TMP.groupby("TIME.year")
    .mean(dim="TIME"),
    color="tab:green",
    linestyle="dashed",
    label="N section (observations)",
)
axs[0, 1].plot(
    np.arange(1993, 2021, 1),
    weighted_mean(N_overflow)
    .votemper.groupby("time_counter.year")
    .mean(dim="time_counter"),
    color="tab:green",
    label="N section (GLORYS12)",
)
axs[0, 1].set_ylim(-0.65, -0.1)
axs[0, 1].set_ylabel("Temperature (°C)")
axs[0, 1].grid()
axs[0, 1].legend(loc="upper left")
axs[0, 1].add_artist(
    AnchoredText("b)", prop=dict(size=15), frameon=True, loc="lower left")
)

############################################
# --------- Row 2: Salinity ----------------
############################################

# S section (left)
axs[1, 0].plot(
    Annual_S_section_salinity["Year"][:23],
    Annual_S_section_salinity["Avg"][:23] / convert_abSal_psu,
    color="tab:blue",
    linestyle="dashed",
    label="S section (observations)",
)

axs[1, 0].plot(
    S_obs_overflow.S.mean(dim=("station", "depth"))
    .groupby("time.year")
    .mean(dim="time")
    .year,
    S_obs_overflow.S.mean(dim=("station", "depth"))
    .groupby("time.year")
    .mean(dim="time"),
    color="k",
    linestyle="dashed",
    label="S section (observations)",
)

axs[1, 0].plot(
    np.arange(1993, 2021, 1),
    weighted_mean(S_overflow)
    .vosaline.groupby("time_counter.year")
    .mean(dim="time_counter"),
    color="k",
    label="S section (GLORYS12)",
)
axs[1, 0].set_ylim(34.885, 34.92)
axs[1, 0].set_ylabel("Salinity (psu)")
axs[1, 0].grid()
axs[1, 0].add_artist(
    AnchoredText("c)", prop=dict(size=15), frameon=True, loc="lower left")
)
# axs[1, 0].legend()

# N section (right)
axs[1, 1].plot(
    N_obs_overflow.mean(dim=("STATION", "DEPTH"))
    .SAL.groupby("TIME.year")
    .mean(dim="TIME")
    .year,
    N_obs_overflow.mean(dim=("STATION", "DEPTH"))
    .SAL.groupby("TIME.year")
    .mean(dim="TIME"),
    color="tab:green",
    linestyle="dashed",
    label="N section (observations)",
)
axs[1, 1].set_ylim(34.885, 34.92)
axs[1, 1].plot(
    np.arange(1993, 2021, 1),
    weighted_mean(N_overflow)
    .vosaline.groupby("time_counter.year")
    .mean(dim="time_counter"),
    color="tab:green",
    label="N section (GLORYS12)",
)
axs[1, 1].set_ylabel("Salinity (psu)")
axs[1, 1].grid()
# axs[1, 1].legend()
axs[1, 1].add_artist(
    AnchoredText("d)", prop=dict(size=15), frameon=True, loc="lower left")
)

############################################
# --------- Row 3: Volume transport -------
############################################

# # Volume transport (left)
# axs[2, 0].plot(
#     np.arange(1995, 2024, 1),
#     FBC_overflow_trspt_annual_means,
#     color="gray",
#     linestyle="dashed",
#     label="FBC (observations)",
# )
# axs[2, 0].plot(
#     np.arange(1993, 2021, 1),
#     bl.calculate_transport(S.sel(z=slice(500, None)))
#     .trsp.groupby("time_counter.year")
#     .mean(dim="time_counter"),
#     color="k",
#     label="S section (GLORYS12)",
# )
# axs[2, 0].set_ylabel("volume transport (Sv)")
# axs[2, 0].set_ylim(1.6, 2.9)
# axs[2, 0].grid()
# axs[2, 0].add_artist(
#     AnchoredText("e)", prop=dict(size=15), frameon=True, loc="lower left")
# )
# axs[2, 0].legend(loc="upper left")

# # Empty panel (right)
# axs[2, 1].axis("off")

# X-label only on bottom row
for ax in axs.flat:
    ax.set_xlabel("Year")

plt.tight_layout()
# plt.savefig("Fig3_S_N_section_ts.png", dpi=300, bbox_inches="tight")
plt.show()
